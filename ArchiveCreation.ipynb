# %% [markdown]
# # Archive creation
#
# Accessing thousands of small files on Google Drive is slow. The commands below were used to create archives containing the small files generated by ImageGenerator.ipynb, which will be extracted to the VM instances when needed.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Projet_IIN/InterFaceGAN/ImageLatentCodes
# Out:
# /content/drive/.shortcut-targets-by-id/1Nfas3WFrJDod2dAwf8WeD449mTBDWDad/Projet_IIN/InterFaceGAN/ImageLatentCodes

# %%
# !tar zcvf /content/ImageLatentCodes.tar.gz *.pt
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# tensor5500.pt
# tensor5501.pt
# tensor5502.pt
# tensor5503.pt
# tensor5504.pt
# tensor5505.pt
# tensor5506.pt
# tensor5507.pt
# tensor5508.pt
# tensor5509.pt
# tensor550.pt
# tensor5510.pt
# tensor5511.pt
# tensor5512.pt
# tensor5513.pt
# tensor5514.pt
# tensor5515.pt
# tensor5516.pt
# tensor5517.pt
# tensor5518.pt
# tensor5519.pt
# tensor551.pt
# tensor5520.pt
# tensor5521.pt
# tensor5522.pt
# tensor5523.pt
# tensor5524.pt
# tensor5525.pt
# tensor5526.pt
# tensor5527.pt
# tensor5528.pt
# tensor5529.pt
# tensor552.pt
# tensor5530.pt
# tensor5531.pt
# tensor5532.pt
# tensor5533.pt
# tensor5534.pt
# tensor5535.pt
# tensor5536.pt
# tensor5537.pt
# tensor5538.pt
# tensor5539.pt
# tensor553.pt
# tensor5540.pt
# tensor5541.pt
# tensor5542.pt
# tensor5543.pt
# tensor5544.pt
# tensor5545.pt
# tensor5546.pt
# tensor5547.pt
# tensor5548.pt
# tensor5549.pt
# tensor554.pt
# tensor5550.pt
# tensor5551.pt
# ...

# %%
# !cp /content/ImageLatentCodes.tar.gz ../

# %%
# %cd ../../
# Out:
# /content/drive/.shortcut-targets-by-id/1Nfas3WFrJDod2dAwf8WeD449mTBDWDad/Projet_IIN

# %%
# %cd InterFaceGAN/test_dataset
# Out:
# /content/drive/.shortcut-targets-by-id/1Nfas3WFrJDod2dAwf8WeD449mTBDWDad/Projet_IIN/InterFaceGAN/test_dataset

# %%
# !tar zcvf test_ImageLatentCodes.tar.gz test_ImageLatentCodes
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# test_ImageLatentCodes/tensor4000.pt
# test_ImageLatentCodes/tensor4001.pt
# test_ImageLatentCodes/tensor4002.pt
# test_ImageLatentCodes/tensor4003.pt
# test_ImageLatentCodes/tensor4004.pt
# test_ImageLatentCodes/tensor4005.pt
# test_ImageLatentCodes/tensor4006.pt
# test_ImageLatentCodes/tensor4007.pt
# test_ImageLatentCodes/tensor4008.pt
# test_ImageLatentCodes/tensor4009.pt
# test_ImageLatentCodes/tensor4010.pt
# test_ImageLatentCodes/tensor4011.pt
# test_ImageLatentCodes/tensor4012.pt
# test_ImageLatentCodes/tensor4013.pt
# test_ImageLatentCodes/tensor4014.pt
# test_ImageLatentCodes/tensor4015.pt
# test_ImageLatentCodes/tensor4016.pt
# test_ImageLatentCodes/tensor4017.pt
# test_ImageLatentCodes/tensor4018.pt
# test_ImageLatentCodes/tensor4019.pt
# test_ImageLatentCodes/tensor4020.pt
# test_ImageLatentCodes/tensor4021.pt
# test_ImageLatentCodes/tensor4022.pt
# test_ImageLatentCodes/tensor4023.pt
# ...

# %%
# !tar zcvf test_UnlabeledImages.tar.gz test_UnlabeledImages
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# test_UnlabeledImages/img4000.jpg
# test_UnlabeledImages/img4001.jpg
# test_UnlabeledImages/img4002.jpg
# test_UnlabeledImages/img4003.jpg
# test_UnlabeledImages/img4004.jpg
# test_UnlabeledImages/img4005.jpg
# test_UnlabeledImages/img4006.jpg
# test_UnlabeledImages/img4007.jpg
# test_UnlabeledImages/img4008.jpg
# test_UnlabeledImages/img4009.jpg
# test_UnlabeledImages/img4010.jpg
# test_UnlabeledImages/img4011.jpg
# test_UnlabeledImages/img4012.jpg
# test_UnlabeledImages/img4013.jpg
# test_UnlabeledImages/img4014.jpg
# test_UnlabeledImages/img4015.jpg
# test_UnlabeledImages/img4016.jpg
# test_UnlabeledImages/img4017.jpg
# test_UnlabeledImages/img4018.jpg
# test_UnlabeledImages/img4019.jpg
# test_UnlabeledImages/img4020.jpg
# test_UnlabeledImages/img4021.jpg
# test_UnlabeledImages/img4022.jpg
# test_UnlabeledImages/img4023.jpg
# test_UnlabeledImages/img4024.jpg
# test_UnlabeledImages/img4025.jpg
# ...

# %%
# %cd ..
# Out:
# /content/drive/.shortcut-targets-by-id/1Nfas3WFrJDod2dAwf8WeD449mTBDWDad/Projet_IIN/InterFaceGAN

# %%
# !tar zcvf UnlabeledImages.tar.gz UnlabeledImages
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# UnlabeledImages/img4000.jpg
# UnlabeledImages/img4001.jpg
# UnlabeledImages/img4002.jpg
# UnlabeledImages/img4003.jpg
# UnlabeledImages/img4004.jpg
# UnlabeledImages/img4005.jpg
# UnlabeledImages/img4006.jpg
# UnlabeledImages/img4007.jpg
# UnlabeledImages/img4008.jpg
# UnlabeledImages/img4009.jpg
# UnlabeledImages/img4010.jpg
# UnlabeledImages/img4011.jpg
# UnlabeledImages/img4012.jpg
# UnlabeledImages/img4013.jpg
# UnlabeledImages/img4014.jpg
# UnlabeledImages/img4015.jpg
# UnlabeledImages/img4016.jpg
# UnlabeledImages/img4017.jpg
# UnlabeledImages/img4018.jpg
# UnlabeledImages/img4019.jpg
# UnlabeledImages/img4020.jpg
# UnlabeledImages/img4021.jpg
# UnlabeledImages/img4022.jpg
# UnlabeledImages/img4023.jpg
# UnlabeledImages/img4024.jpg
# UnlabeledImages/img4025.jpg
# UnlabeledImages/img4026.jpg
# UnlabeledImages/img4027.jpg
# UnlabeledImages/img4028.jpg
# UnlabeledImages/img4029.jpg
# ...

# %%
# %cd /content
# Out:
# /content

# %%
# !ls
# Out:
# drive  ImageLatentCodes.tar.gz	sample_data

# %%
# %mkdir ImageLatentCodes

# %%
# %cd ImageLatentCodes
# Out:
# /content/ImageLatentCodes

# %%
# !tar zxvf ../ImageLatentCodes.tar.gz
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# tensor5500.pt
# tensor5501.pt
# tensor5502.pt
# tensor5503.pt
# tensor5504.pt
# tensor5505.pt
# tensor5506.pt
# tensor5507.pt
# tensor5508.pt
# tensor5509.pt
# tensor550.pt
# tensor5510.pt
# tensor5511.pt
# tensor5512.pt
# tensor5513.pt
# tensor5514.pt
# tensor5515.pt
# tensor5516.pt
# tensor5517.pt
# tensor5518.pt
# tensor5519.pt
# tensor551.pt
# tensor5520.pt
# tensor5521.pt
# tensor5522.pt
# tensor5523.pt
# tensor5524.pt
# tensor5525.pt
# tensor5526.pt
# tensor5527.pt
# tensor5528.pt
# tensor5529.pt
# tensor552.pt
# tensor5530.pt
# tensor5531.pt
# tensor5532.pt
# tensor5533.pt
# tensor5534.pt
# tensor5535.pt
# tensor5536.pt
# tensor5537.pt
# tensor5538.pt
# tensor5539.pt
# tensor553.pt
# tensor5540.pt
# tensor5541.pt
# tensor5542.pt
# tensor5543.pt
# tensor5544.pt
# tensor5545.pt
# tensor5546.pt
# tensor5547.pt
# tensor5548.pt
# tensor5549.pt
# tensor554.pt
# tensor5550.pt
# tensor5551.pt
# ...

# %%
# %cd ..
# !rm ImageLatentCodes.tar.gz
# !tar zcvf ImageLatentCodes.tar.gz ImageLatentCodes
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# ImageLatentCodes/tensor11315.pt
# ImageLatentCodes/tensor13775.pt
# ImageLatentCodes/tensor239.pt
# ImageLatentCodes/tensor3695.pt
# ImageLatentCodes/tensor13340.pt
# ImageLatentCodes/tensor5522.pt
# ImageLatentCodes/tensor12718.pt
# ImageLatentCodes/tensor9125.pt
# ImageLatentCodes/tensor2749.pt
# ImageLatentCodes/tensor12795.pt
# ImageLatentCodes/tensor1716.pt
# ImageLatentCodes/tensor3449.pt
# ImageLatentCodes/tensor12082.pt
# ImageLatentCodes/tensor4815.pt
# ImageLatentCodes/tensor11645.pt
# ImageLatentCodes/tensor2105.pt
# ImageLatentCodes/tensor10308.pt
# ImageLatentCodes/tensor12097.pt
# ImageLatentCodes/tensor11686.pt
# ImageLatentCodes/tensor5817.pt
# ImageLatentCodes/tensor11048.pt
# ImageLatentCodes/tensor11890.pt
# ImageLatentCodes/tensor13183.pt
# ImageLatentCodes/tensor7468.pt
# ImageLatentCodes/tensor2407.pt
# ImageLatentCodes/tensor366.pt
# ImageLatentCodes/tensor7073.pt
# ...

# %%
# !mv /content/drive/MyDrive/Projet_IIN/InterFaceGAN/ImageLatentCodes.tar.gz /content/drive/MyDrive/Projet_IIN/InterFaceGAN/ImageLatentCodes.tar.gz.bak
# !cp ImageLatentCodes.tar.gz /content/drive/MyDrive/Projet_IIN/InterFaceGAN/
